# %%
import utils
import numpy as np 
import matplotlib.pyplot as plt 

x_data, y_data = utils.load_dataset_sice('D:\\projects\\_datasets\\SICE\\Dataset_Part1')

# %%
data_gen = utils.data_generator(x_data, y_data, batch_size=4, crop_size=512, mode='detail')

# %%
x, y = next(data_gen)
plt.figure(figsize=(60,80))
for j in range(4):
    plt.subplot(1,4,j+1,)
    plt.imshow(x[j], vmin=0, vmax=1)
plt.figure(figsize=(60,80))
for j in range(4):
    plt.subplot(1,4,j+1)
    plt.imshow(y[j],vmin=0, vmax=1)
 
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
